# %% [markdown]
# # **Laboratorio 03**
# ### **Metodos Numericos - 2022 - I**
# Juan Esteban Oviedo Garcia
#
# LinkedIn: https://www.linkedin.com/in/juan-esteban-oviedo-garcia-b07811207/
#
# Python for Data Science
#
# ![joviedogcognitiveclasspython101fordatascience.png](data:image/png;base64,...)

# %% [markdown]
# Data Analysis with Python
#
# ![joviedogcognitiveclassaapplieddataanalysiswithpython.png](data:image/png;base64,...)

# %% [markdown]
# Data Visualization with Python
#
# ![joviedogcognitiveclassdatavisualizationwithpython.png](data:image/png;base64,...)
